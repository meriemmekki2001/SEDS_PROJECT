# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from PIL import Image
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2024-02-15 16:13:51.320431: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-15 16:13:51.390536: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-15 16:13:51.584643: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-15 16:13:51.584732: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-15 16:13:51.597419: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-15 16:13:51.636394: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-15 16:13:51.637521: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-15 16:13:53.481000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # load data using tf.keras.utils.image_dataset_from_directory

# %%
data_dir = '/home/meriem-mk/Downloads/food101/food-101/food-101/images'
data_dir = pathlib.Path(data_dir).with_suffix('')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 4000

# %%
batch_size = 34
img_height = 512
img_width = 512

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4000 files belonging to 4 classes.
# Using 3200 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4000 files belonging to 4 classes.
# Using 800 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['french_fries', 'pizza', 'spaghetti_carbonara', 'waffles']

# %% [markdown]
# <h5>  Here I deleted the majority of subdirectories and only kept 4 subdirectories from the entire food101 dataset(4 classes) </h5>

# %% [markdown]
# # visualize random images from the dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# # image_batch

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (34, 512, 512, 3)
# (34,)

# %% [markdown]
# # Standardize the data
# The RGB channel values are in the [0, 255] range. This is not ideal for a neural network
#
# Here, we standardize values to be in the [0, 1] range by using tf.keras.layers.Rescaling:

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9926471

# %% [markdown]
# # A basic Keras model
# (from the official TF documentation's tutorial for image classification)
#
# The Keras Sequential model consists of three convolution blocks (tf.keras.layers.Conv2D) with a max pooling layer (tf.keras.layers.MaxPooling2D) in each of them. There's a fully-connected layer (tf.keras.layers.Dense) with 128 units on top of it that is activated by a ReLU activation function ('relu'). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
num_classes = 4

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 512, 512, 3)       0
#
#  conv2d (Conv2D)             (None, 512, 512, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 262144)            0
#
#  dense (Dense)               (None, 128)               33554560
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 33578660 (128.09 MB)
# Trainable params: 33578660 (128.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 95/95 [==============================] - 65s 669ms/step - loss: 1.6687 - accuracy: 0.3697 - val_loss: 1.1668 - val_accuracy: 0.4925
# Epoch 2/10
# 95/95 [==============================] - 66s 695ms/step - loss: 1.0724 - accuracy: 0.5562 - val_loss: 1.0959 - val_accuracy: 0.5312
# Epoch 3/10
# 95/95 [==============================] - 70s 734ms/step - loss: 0.7578 - accuracy: 0.7134 - val_loss: 1.1264 - val_accuracy: 0.5625
# Epoch 4/10
# 95/95 [==============================] - 69s 725ms/step - loss: 0.3878 - accuracy: 0.8641 - val_loss: 1.3777 - val_accuracy: 0.5763
# Epoch 5/10
# 95/95 [==============================] - 68s 716ms/step - loss: 0.1676 - accuracy: 0.9481 - val_loss: 1.9554 - val_accuracy: 0.5763
# Epoch 6/10
# 95/95 [==============================] - 68s 717ms/step - loss: 0.0584 - accuracy: 0.9856 - val_loss: 2.5170 - val_accuracy: 0.5500
# Epoch 7/10
# 95/95 [==============================] - 68s 717ms/step - loss: 0.1537 - accuracy: 0.9528 - val_loss: 2.4873 - val_accuracy: 0.4913
# Epoch 8/10
# 95/95 [==============================] - 67s 710ms/step - loss: 0.0709 - accuracy: 0.9797 - val_loss: 3.0487 - val_accuracy: 0.5250
# Epoch 9/10
# 95/95 [==============================] - 68s 717ms/step - loss: 0.0379 - accuracy: 0.9925 - val_loss: 3.0558 - val_accuracy: 0.5050
# Epoch 10/10
# 95/95 [==============================] - 146s 2s/step - loss: 0.0227 - accuracy: 0.9953 - val_loss: 3.1264 - val_accuracy: 0.5462

# %%
model.save('model_1.keras')

# %%
model = tf.keras.models.load_model('model_1.keras')

# %% [markdown]
# # Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 57% accuracy on the validation set. (Overffiting)
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# # Possible Solutions ?
# <ul>
#     <li> Data Augmentation </li>
#     <li> Dropout </li>
#     <li> Transfer Learning</li>
#
# </ul>

# %% [markdown]
# # Dropout
# Apply dropout to a layer randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.

# %%
model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 512, 512, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 512, 512, 16)      448
#
#  max_pooling2d_12 (MaxPooli  (None, 256, 256, 16)      0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 32)      4640
#
#  max_pooling2d_13 (MaxPooli  (None, 128, 128, 32)      0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_14 (MaxPooli  (None, 64, 64, 64)        0
#  ng2D)
#
#  dropout_3 (Dropout)         (None, 64, 64, 64)        0
#
#  flatten_4 (Flatten)         (None, 262144)            0
#
#  dense_5 (Dense)             (None, 128)               33554560
#
#  outputs (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 33578660 (128.09 MB)
# Trainable params: 33578660 (128.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 95/95 [==============================] - 80s 846ms/step - loss: 1.2156 - accuracy: 0.4478 - val_loss: 1.1320 - val_accuracy: 0.5425
# Epoch 2/15
# 95/95 [==============================] - 150s 2s/step - loss: 1.0255 - accuracy: 0.5822 - val_loss: 1.0586 - val_accuracy: 0.5537
# Epoch 3/15
# 95/95 [==============================] - 150s 2s/step - loss: 0.8278 - accuracy: 0.6750 - val_loss: 0.9647 - val_accuracy: 0.6150
# Epoch 4/15
# 95/95 [==============================] - 148s 2s/step - loss: 0.5678 - accuracy: 0.7966 - val_loss: 1.2478 - val_accuracy: 0.5925
# Epoch 5/15
# 95/95 [==============================] - 146s 2s/step - loss: 0.3161 - accuracy: 0.8906 - val_loss: 1.7618 - val_accuracy: 0.5612
# Epoch 6/15
# 95/95 [==============================] - 161s 2s/step - loss: 0.1513 - accuracy: 0.9569 - val_loss: 1.8384 - val_accuracy: 0.5600
# Epoch 7/15
# 95/95 [==============================] - 162s 2s/step - loss: 0.0840 - accuracy: 0.9791 - val_loss: 1.9106 - val_accuracy: 0.5913
# Epoch 8/15
# 95/95 [==============================] - 155s 2s/step - loss: 0.0445 - accuracy: 0.9887 - val_loss: 2.2851 - val_accuracy: 0.5987
# Epoch 9/15
# 95/95 [==============================] - 153s 2s/step - loss: 0.0593 - accuracy: 0.9825 - val_loss: 2.4729 - val_accuracy: 0.5838
# Epoch 10/15
# 95/95 [==============================] - 147s 2s/step - loss: 0.0383 - accuracy: 0.9903 - val_loss: 2.6353 - val_accuracy: 0.5838
# Epoch 11/15
# 95/95 [==============================] - 145s 2s/step - loss: 0.0274 - accuracy: 0.9925 - val_loss: 2.7912 - val_accuracy: 0.5750
# Epoch 12/15
# 95/95 [==============================] - 144s 2s/step - loss: 0.0308 - accuracy: 0.9912 - val_loss: 2.4754 - val_accuracy: 0.5512
# Epoch 13/15
# 95/95 [==============================] - 146s 2s/step - loss: 0.0325 - accuracy: 0.9928 - val_loss: 2.9103 - val_accuracy: 0.5863
# Epoch 14/15
# 95/95 [==============================] - 146s 2s/step - loss: 0.0128 - accuracy: 0.9972 - val_loss: 2.9144 - val_accuracy: 0.5550
# Epoch 15/15
# 95/95 [==============================] - 143s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.1938 - val_accuracy: 0.5775

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.3),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 95/95 [==============================] - 156s 2s/step - loss: 1.7775 - accuracy: 0.3847 - val_loss: 1.4256 - val_accuracy: 0.2688
# Epoch 2/15
# 95/95 [==============================] - 156s 2s/step - loss: 1.0816 - accuracy: 0.5612 - val_loss: 1.0152 - val_accuracy: 0.6000
# Epoch 3/15
# 95/95 [==============================] - 160s 2s/step - loss: 0.8832 - accuracy: 0.6622 - val_loss: 0.9945 - val_accuracy: 0.6112
# Epoch 4/15
# 95/95 [==============================] - 160s 2s/step - loss: 0.6127 - accuracy: 0.7778 - val_loss: 1.1476 - val_accuracy: 0.6025
# Epoch 5/15
# 95/95 [==============================] - 174s 2s/step - loss: 0.3664 - accuracy: 0.8706 - val_loss: 1.2644 - val_accuracy: 0.6413
# Epoch 6/15
# 95/95 [==============================] - 156s 2s/step - loss: 0.2207 - accuracy: 0.9256 - val_loss: 1.5475 - val_accuracy: 0.6200
# Epoch 7/15
# 95/95 [==============================] - 152s 2s/step - loss: 0.1612 - accuracy: 0.9425 - val_loss: 1.7378 - val_accuracy: 0.5975
# Epoch 8/15
# 95/95 [==============================] - 155s 2s/step - loss: 0.1011 - accuracy: 0.9663 - val_loss: 1.8268 - val_accuracy: 0.6200
# Epoch 9/15
# 95/95 [==============================] - 155s 2s/step - loss: 0.0863 - accuracy: 0.9691 - val_loss: 2.0799 - val_accuracy: 0.6413
# Epoch 10/15
# 95/95 [==============================] - 146s 2s/step - loss: 0.1011 - accuracy: 0.9694 - val_loss: 2.0442 - val_accuracy: 0.6125
# Epoch 11/15
# 95/95 [==============================] - 141s 1s/step - loss: 0.0594 - accuracy: 0.9819 - val_loss: 2.2975 - val_accuracy: 0.6075
# Epoch 12/15
# 95/95 [==============================] - 141s 1s/step - loss: 0.0760 - accuracy: 0.9753 - val_loss: 2.8783 - val_accuracy: 0.6212
# Epoch 13/15
# 95/95 [==============================] - 140s 1s/step - loss: 0.0472 - accuracy: 0.9862 - val_loss: 2.5617 - val_accuracy: 0.5888
# Epoch 14/15
# 95/95 [==============================] - 139s 1s/step - loss: 0.0626 - accuracy: 0.9822 - val_loss: 2.1636 - val_accuracy: 0.5888
# Epoch 15/15
# 95/95 [==============================] - 123s 1s/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 3.0581 - val_accuracy: 0.5850

# %%
model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.3),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 12
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/12
# 95/95 [==============================] - 75s 781ms/step - loss: 3.2096 - accuracy: 0.2978 - val_loss: 1.3464 - val_accuracy: 0.3550
# Epoch 2/12
# 95/95 [==============================] - 90s 945ms/step - loss: 1.2272 - accuracy: 0.4519 - val_loss: 1.2902 - val_accuracy: 0.4487
# Epoch 3/12
# 95/95 [==============================] - 91s 963ms/step - loss: 1.1472 - accuracy: 0.4984 - val_loss: 1.3923 - val_accuracy: 0.3063
# Epoch 4/12
# 95/95 [==============================] - 96s 1s/step - loss: 1.0869 - accuracy: 0.5478 - val_loss: 1.3393 - val_accuracy: 0.3288
# Epoch 5/12
# 95/95 [==============================] - 102s 1s/step - loss: 0.9707 - accuracy: 0.6122 - val_loss: 1.1879 - val_accuracy: 0.4538
# Epoch 6/12
# 95/95 [==============================] - 103s 1s/step - loss: 0.8152 - accuracy: 0.6806 - val_loss: 1.1415 - val_accuracy: 0.5487
# Epoch 7/12
# 95/95 [==============================] - 99s 1s/step - loss: 0.6317 - accuracy: 0.7534 - val_loss: 1.3338 - val_accuracy: 0.5225
# Epoch 8/12
# 95/95 [==============================] - 89s 941ms/step - loss: 0.4883 - accuracy: 0.8178 - val_loss: 1.4821 - val_accuracy: 0.5400
# Epoch 9/12
# 95/95 [==============================] - 89s 931ms/step - loss: 0.3742 - accuracy: 0.8612 - val_loss: 1.9081 - val_accuracy: 0.5300
# Epoch 10/12
# 95/95 [==============================] - 77s 812ms/step - loss: 0.3161 - accuracy: 0.8853 - val_loss: 1.9433 - val_accuracy: 0.5350
# Epoch 11/12
# 95/95 [==============================] - 89s 940ms/step - loss: 0.2484 - accuracy: 0.9112 - val_loss: 2.4304 - val_accuracy: 0.5288
# Epoch 12/12
# 95/95 [==============================] - 82s 857ms/step - loss: 0.2325 - accuracy: 0.9191 - val_loss: 2.6631 - val_accuracy: 0.5200

# %%
model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
#
# 95/95 [==============================] - 89s 938ms/step - loss: 0.3105 - accuracy: 0.8878 - val_loss: 0.9672 - val_accuracy: 0.7262
# Epoch 45/55
# 95/95 [==============================] - 90s 951ms/step - loss: 0.4025 - accuracy: 0.8541 - val_loss: 0.7738 - val_accuracy: 0.7625
# Epoch 46/55
# 95/95 [==============================] - 90s 947ms/step - loss: 0.3186 - accuracy: 0.8819 - val_loss: 0.7922 - val_accuracy: 0.7538
# Epoch 47/55
# 95/95 [==============================] - 88s 924ms/step - loss: 0.3506 - accuracy: 0.8700 - val_loss: 0.8219 - val_accuracy: 0.7625
# Epoch 48/55
# 95/95 [==============================] - 88s 929ms/step - loss: 0.3457 - accuracy: 0.8772 - val_loss: 0.9249 - val_accuracy: 0.7362
# Epoch 49/55
# 95/95 [==============================] - 88s 925ms/step - loss: 0.2964 - accuracy: 0.8959 - val_loss: 0.8735 - val_accuracy: 0.7563
# Epoch 50/55
# 95/95 [==============================] - 88s 923ms/step - loss: 0.2824 - accuracy: 0.8988 - val_loss: 0.8518 - val_accuracy: 0.7375
# Epoch 51/55
# 95/95 [==============================] - 88s 922ms/step - loss: 0.2616 - accuracy: 0.9009 - val_loss: 0.8907 - val_accuracy: 0.7725
# Epoch 52/55
# 95/95 [==============================] - 88s 927ms/step - loss: 0.2706 - accuracy: 0.9006 - val_loss: 0.8587 - val_accuracy: 0.7675
# Epoch 53/55
# 95/95 [==============================] - 88s 920ms/step - loss: 0.2613 - accuracy: 0.9084 - val_loss: 0.9109 - val_accuracy: 0.7400
# Epoch 54/55
# 95/95 [==============================] - 88s 922ms/step - loss: 0.2302 - accuracy: 0.9191 - val_loss: 0.8619 - val_accuracy: 0.7688
# Epoch 55/55
# 95/95 [==============================] - 90s 950ms/step - loss: 0.2526 - accuracy: 0.9116 - val_loss: 0.8536 - val_accuracy: 0.7650

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Save the model
model.save('model_2.keras')

# %% [markdown]
# # Predict on new data

# %%
# load the model
model = tf.keras.models.load_model('models/model_2.keras')

# %% [markdown]
#  <h3>here I'm using a new picture downloaded from google for prediction the food in the pricture is a pizza, let's see what will be the prediction of the model </h3>

# %%
image_path = 'images/pizza.jpg'

img = tf.keras.utils.load_img(
    image_path, target_size=(512, 512)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 119ms/step
# This image most likely belongs to pizza with a 99.85 percent confidence.

# %%
image_path = 'images/waffles2.jpg'

img = tf.keras.utils.load_img(
    image_path, target_size=(512, 512)
)
img = tf.expand_dims(img, 0)

predictions = model.predict(img)

score = tf.nn.softmax(predictions)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# This image most likely belongs to waffles with a 99.90 percent confidence.

# %%
image_path = 'images/fries.jpg'

img = tf.keras.utils.load_img(
    image_path, target_size=(512, 512)
)
img = tf.expand_dims(img, 0)

predictions = model.predict(img)

score = tf.nn.softmax(predictions)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# This image most likely belongs to french_fries with a 94.19 percent confidence.

# %%
image_path = 'images/spaghetti.jpg'

img = tf.keras.utils.load_img(
    image_path, target_size=(512, 512)
)
img = tf.expand_dims(img, 0)

predictions = model.predict(img)

score = tf.nn.softmax(predictions)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# This image most likely belongs to spaghetti_carbonara with a 99.90 percent confidence.

# %% [markdown]
# # yaaaaaaaaaaay the model guessed it right
